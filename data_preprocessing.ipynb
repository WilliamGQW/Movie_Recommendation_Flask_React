# %%
import numpy as np
import pandas as pd
import json

# %%
Movies = pd.read_csv('data/Movies.csv', index_col=False) 
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 22 columns):
# budget                  199 non-null int64
# genres                  199 non-null object
# homepage                152 non-null object
# id                      199 non-null int64
# keywords                199 non-null object
# original_language       199 non-null object
# original_title          199 non-null object
# overview                199 non-null object
# popularity              199 non-null float64
# production_companies    199 non-null object
# production_countries    199 non-null object
# release_date            199 non-null object
# revenue                 199 non-null int64
# runtime                 199 non-null int64
# spoken_languages        199 non-null object
# status                  199 non-null object
# tagline                 193 non-null object
# title                   199 non-null object
# vote_average            199 non-null float64
# vote_count              199 non-null int64
# cast                    199 non-null object
# crew                    199 non-null object
# dtypes: float64(2), int64(5), object(15)
# memory usage: 34.3+ KB

# %%
Movies = Movies.drop(['budget', 'homepage','keywords','original_title','production_companies','production_countries','revenue','spoken_languages','status','tagline'], axis=1)
Movies = Movies.rename(columns={'cast': 'actors', 'crew': 'director', 'release_date': 'release_year'})
Movies = Movies.drop([28])
Movies = Movies.reset_index(drop=True)
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 12 columns):
# genres               198 non-null object
# id                   198 non-null int64
# original_language    198 non-null object
# overview             198 non-null object
# popularity           198 non-null float64
# release_year         198 non-null object
# runtime              198 non-null int64
# title                198 non-null object
# vote_average         198 non-null float64
# vote_count           198 non-null int64
# actors               198 non-null object
# director             198 non-null object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 18.7+ KB

# %%
# year = Movies.loc[0, 'release_year'][-2:]
# shortYrAsInt = int(year)
# longYear = 0
# if (shortYrAsInt <= 20):
#     longYear = shortYrAsInt + 2000
# else:
#     longYear = shortYrAsInt + 1900

# print(longYear)
# Movies.loc[0, 'release_year'] = longYear
# Movies.loc[0, 'release_year']

# %%
for i in range (Movies.shape[0]):
    year = Movies.loc[i, 'release_year'][-2:]
    shortYrAsInt = int(year)
    longYear = 0
    if (shortYrAsInt <= 20):
        longYear = shortYrAsInt + 2000
    else:
        longYear = shortYrAsInt + 1900
    Movies.loc[i, 'release_year'] = longYear
    
    y=json.loads(Movies.loc[i,'actors'])
    l = [d['name'] for d in y]
    Movies.at[i,'actors'] = ','.join(l)
    
    y2 = json.loads(Movies.loc[i,'director'])
    l2 = [d['name'] for d in y2 if d['job']=='Director']
    Movies.at[i,'director'] = ','.join(l2)
    
    y3 = json.loads(Movies.loc[i,'genres'])
    l3 = [d['name'] for d in y3]
    Movies.at[i,'genres'] = ','.join(l3)

# %%
Movies.loc[:,'actors']
# Out:
# 0      Sam Worthington,Zoe Saldana,Sigourney Weaver,S...
# 1      Johnny Depp,Orlando Bloom,Keira Knightley,Stel...
# 2      Daniel Craig,Christoph Waltz,Léa Seydoux,Ralph...
# 3      Christian Bale,Michael Caine,Gary Oldman,Anne ...
# 4      Taylor Kitsch,Lynn Collins,Samantha Morton,Wil...
#                              ...
# 193    D. B. Sweeney,Alfre Woodard,Ossie Davis,Max Ca...
# 194    Ben Stiller,Rami Malek,Rebel Wilson,Robin Will...
# 195    Will Ferrell,Brad Pitt,Tina Fey,Jonah Hill,Dav...
# 196    Daniel Radcliffe,Rupert Grint,Emma Watson,Rich...
# 197    Jeff Bridges,Ryan Reynolds,Kevin Bacon,Stephan...
# Name: actors, Length: 198, dtype: object

# %%
Movies.loc[:,'director']
# Out:
# 0                   James Cameron
# 1                  Gore Verbinski
# 2                      Sam Mendes
# 3               Christopher Nolan
# 4                  Andrew Stanton
#                   ...
# 193    Ralph Zondag,Eric Leighton
# 194                    Shawn Levy
# 195                   Tom McGrath
# 196                Chris Columbus
# 197              Robert Schwentke
# Name: director, Length: 198, dtype: object

# %%
Movies.loc[:,'genres']
# Out:
# 0            Action,Adventure,Fantasy,Science Fiction
# 1                            Adventure,Fantasy,Action
# 2                              Action,Adventure,Crime
# 3                         Action,Crime,Drama,Thriller
# 4                    Action,Adventure,Science Fiction
#                             ...
# 193                                  Animation,Family
# 194                   Adventure,Comedy,Fantasy,Family
# 195    Animation,Action,Comedy,Family,Science Fiction
# 196                          Adventure,Fantasy,Family
# 197                       Fantasy,Action,Comedy,Crime
# Name: genres, Length: 198, dtype: object

# %%
Movies
# Out:
#                                              genres      id original_language  \
# 0          Action,Adventure,Fantasy,Science Fiction   19995                en
# 1                          Adventure,Fantasy,Action     285                en
# 2                            Action,Adventure,Crime  206647                en
# 3                       Action,Crime,Drama,Thriller   49026                en
# 4                  Action,Adventure,Science Fiction   49529                en
# ..                                              ...     ...               ...
# 193                                Animation,Family   10567                en
# 194                 Adventure,Comedy,Fantasy,Family  181533                en
# 195  Animation,Action,Comedy,Family,Science Fiction   38055                en
# 196                        Adventure,Fantasy,Family     671                en
# 197                     Fantasy,Action,Comedy,Crime   49524                en
#
#                                               overview  popularity  \
# 0    In the 22nd century, a paraplegic Marine is di...  150.437577
# 1    Captain Barbossa, long believed to be dead, ha...  139.082615
# 2    A cryptic message from Bond’s past sends him o...  107.376788
# 3    Following the death of District Attorney Harve...  112.312950
# 4    John Carter is a war-weary, former military ca...   43.926995
# ..                                                 ...         ...
# 193  An orphaned dinosaur raised by lemurs joins an...   26.548594
# 194  When the magic powers of The Tablet of Ahkmenr...  115.597753
# 195  Bumbling supervillain Megamind finally defeats...   68.757242
# 196  Harry Potter has lived under the stairs at his...  109.984351
# 197  A recently slain cop joins a team of undead po...   39.448066
#
#      release_year  runtime                                     title  \
# 0            2009      162                                    Avatar
# 1            2007      169  Pirates of the Caribbean: At World's End
# 2            2015      148                                   Spectre
# 3            2012      165                     The Dark Knight Rises
# 4            2012      132                               John Carter
# ..            ...      ...                                       ...
# 193          2000       82                                  Dinosaur
# 194          2014       97   Night at the Museum: Secret of the Tomb
# 195          2010       95                                  Megamind
# 196          2001      152  Harry Potter and the Philosopher's Stone
# 197          2013       96                                  R.I.P.D.
#
#      vote_average  vote_count  \
# 0             7.2       11800
# 1             6.9        4500
# 2             6.3        4466
# 3             7.6        9106
# 4             6.1        2124
# ..            ...         ...
# 193           6.2         542
# 194           6.1        1851
# 195           6.7        1918
# 196           7.5        7006
# 197           5.4        1260
#
#                                                 actors  \
# 0    Sam Worthington,Zoe Saldana,Sigourney Weaver,S...
# 1    Johnny Depp,Orlando Bloom,Keira Knightley,Stel...
# 2    Daniel Craig,Christoph Waltz,Léa Seydoux,Ralph...
# 3    Christian Bale,Michael Caine,Gary Oldman,Anne ...
# 4    Taylor Kitsch,Lynn Collins,Samantha Morton,Wil...
# ..                                                 ...
# 193  D. B. Sweeney,Alfre Woodard,Ossie Davis,Max Ca...
# 194  Ben Stiller,Rami Malek,Rebel Wilson,Robin Will...
# 195  Will Ferrell,Brad Pitt,Tina Fey,Jonah Hill,Dav...
# 196  Daniel Radcliffe,Rupert Grint,Emma Watson,Rich...
# 197  Jeff Bridges,Ryan Reynolds,Kevin Bacon,Stephan...
#
#                        director
# 0                 James Cameron
# 1                Gore Verbinski
# 2                    Sam Mendes
# 3             Christopher Nolan
# 4                Andrew Stanton
# ..                          ...
# 193  Ralph Zondag,Eric Leighton
# 194                  Shawn Levy
# 195                 Tom McGrath
# 196              Chris Columbus
# 197            Robert Schwentke
#
# [198 rows x 12 columns]

# %%
Movies.to_csv('data/Movies_cleaned.csv',index=False)
